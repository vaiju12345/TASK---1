# %% [markdown]
# <a href="https://colab.research.google.com/github/vaiju12345/TASK---1/blob/main/Copy_of_Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TASK 1

# %%
# 1. Program to find the largest of three numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a > b and a > c:
    print("Largest is:", a)

elif b > c:
    print("Largest is:", b)

else:
    print("Largest is:", c)
# Out:
# Enter first number: 3
# Enter second number: 4
# Enter third number: 3
# Largest is: 4

# %%
# 2. Program to check leap year

year = int(input("Enter year: "))

if year % 4 == 0:
    print(year, "is a leap year.")

else:
    print(year, "is not a leap year.")
# Out:
# Enter year: 2004
# 2004 is a leap year.

# %%
# 3. Program to check vowel or consonant

ch = input("Enter a letter: ").lower()

if ch == 'a' or ch == 'e' or ch == 'i' or ch == 'o' or ch == 'u':
    print("Vowel")

else:
    print("Consonant")
# Out:
# Enter a letter: s
# Consonant

# %%
 4. Program to check divisibility by 5 and 11

n = int(input("Enter number: "))

if n % 5 == 0 and n % 11 == 0:
    print(n, "is divisible by both 5 and 11")

else:
    print(n, "is not divisible by both 5 and 11")
# Out:
# Enter number: 196
# 196 is not divisible by both 5 and 11

# %%
# 5. Sum of first N natural numbers using while loop

n = int(input("Enter value of n: "))

sum = 0
i = 1

while i <= n:
    sum = sum + i
    i = i + 1

print("Sum =", sum)
# Out:
# Enter value of n: 25
# Sum = 325

# %%
# 6. Multiplication table using while loop

n = int(input("Enter a number: "))

i = 1

while i <= 10:
    print(n, "x", i, "=", n * i)
    i = i + 1
# Out:
# Enter a number: 4
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40

# %%
# 7. Pyramid pattern

rows = 5

for i in range(1, rows + 1):
    print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
# 8. Number pattern

for i in range(1, 6):
    for j in range(1, i + 1):
        print(j, end="")

    print()
# Out:
# 1
# 12
# 123
# 1234
# 12345
